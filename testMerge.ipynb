# %%
import pandas as pd

# %%
ans = [1250,
1958,
3250,
3917,
6958,
7042,
10208,
9250,
11417,
11125,
15375,
14625,
14875,
15541,
17417,
207958,
20042,
23208,
23167,
23042,
]

# %%
df = pd.DataFrame({'time':ans}, index = [x for x in range(10, 210, 10)])
df = df.drop(df.index[-5])
df.plot()
# Out:
# <AxesSubplot:>
