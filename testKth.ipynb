# %%
import pandas as pd

# %%
ans = [375,
375,
750,
792,
583,
709,
500,
583,
1250,
1500,
459,
1041,
1417,
3000,
1458,
2667,
1250,
542,
3917,
1791,
]

# %%
df = pd.DataFrame({'time': ans}, index = [x for x in range(10, 210, 10)])

# %%
df.plot()
# Out:
# <AxesSubplot:>
