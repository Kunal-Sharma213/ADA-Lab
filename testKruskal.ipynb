# %%
import pandas as pd

# %%
index = [0,
6,
6,
10,
21,
21,
28,
45,
55,
78,
91,
91,
105,
120,
120,
136,
136,
153,
171,
171,]

# %%
ans = [375,
3375,
3792,
6500,
14792,
15667,
20542,
36208,
57292,
70459,
76583,
78375,
93583,
109334,
111833,
128583,
137000,
144166,
160917,
167542,
]

# %%
df = pd.DataFrame({'time': ans}, index = index)
df.plot()
# Out:
# <AxesSubplot:>
